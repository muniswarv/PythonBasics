# %% [markdown]
# # Python Data Types & Operations: Interview Exam
# ### Objective: Self-Validation & Interview Prep
# **Instructions:**
# 1. Try to solve the code problems in the empty cells provided.
# 2. If it's a theoretical question, write your answer as a comment or Markdown.
# 3. Check your answers against the 'Answer Key' at the bottom of the notebook.

# %% [markdown]
# ### Q1 (Numeric)
# How do you distinguish between `/` and `//` operators in Python?

# %% [markdown]
# ### Q2 (Numeric)
# Explain the result of `0.1 + 0.2 == 0.3`. Why does this happen?

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %%
0.1 + 0.2 >= 0.3
# Out:
# True

# %%
0.1 + 0.2 <= 0.3
# Out:
# False

# %%
abs( (0.1 + 0.2) - 0.3 ) < 0.0000000001
# Out:
# True

# %%
### Q3 (Numeric)
How do you convert an integer to a hexadecimal string?

# %% [markdown]
# ### Q4 (Numeric)
# What is the result of `type(1/1)`?

# %%
type(1/1)
# Out:
# float

# %%
type(1//1)
# Out:
# int

# %% [markdown]
# ### Q5 (Numeric)
# How do you find the absolute value of a complex number?

# %% [markdown]
# ### Q6 (Numeric)
# What is the behavior of `round(2.5)` vs `round(3.5)` in Python?

# %%
A=round(2.50000000000000000000000000000000001)
print(A)
# Out:
# 2

# %% [markdown]
# ### Q7 (Numeric)
# How do you represent an 'Infinity' value in Python floats?

# %% [markdown]
# ### Q8 (Numeric)
# What is the difference between `math.floor()` and `math.trunc()`?

# %% [markdown]
# ### Q9 (Numeric)
# How do you check if a number is a `NaN`?

# %% [markdown]
# ### Q10 (Numeric)
# Does Python have a limit on the size of an integer?

# %%
a=55555555555555555555555555555555555555555555555555555557777777777777777777777777777777777777777775
print(int(a))
# Out:
# 55555555555555555555555555555555555555555555555555555557777777777777777777777777777777777777777775

# %% [markdown]
# ### Q11 (String)
# Strings are immutable. What does this mean in practice?

# %% [markdown]
# ### Q12 (String)
# How do you reverse a string using slicing?

# %% [markdown]
# ### Q13 (String)
# What is the difference between `.find()` and `.index()`?

# %%
a = ("a,b,c,d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 a = ("a,b,c,d")
# ----> 2 a.index()
#
# TypeError: index expected at least 1 argument, got 0

# %% [markdown]
# ### Q14 (String)
# Explain 'f-strings' and why they are preferred over `.format()`.

# %%
print(f"{names"},{"age"}")
# Out:
#   Cell In[24], line 1
#     print(f"{names"},{"age"}")
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Q15 (String)
# How do you check if a string contains only alphanumeric characters?

# %% [markdown]
# ### Q16 (String)
# What is the output of `'Python' * 2`?

# %% [markdown]
# ### Q17 (String)
# How do you remove leading and trailing whitespace?

# %% [markdown]
# ### Q18 (String)
# How do you split a string into a list based on a delimiter?

# %% [markdown]
# ### Q19 (String)
# What is the difference between `is` and `==` for string comparison?

# %% [markdown]
# ### Q20 (String)
# How do you check if a string starts with a specific prefix?

# %% [markdown]
# ### Q21 (Sequence)
# What is the primary difference between a List and a Tuple?

# %% [markdown]
# ### Q22 (Sequence)
# How do you add an element to the end of a list?

# %% [markdown]
# ### Q23 (Sequence)
# What is the difference between `.append()` and `.extend()`?

# %% [markdown]
# ### Q24 (Sequence)
# How do you create a 'Deep Copy' of a list?

# %% [markdown]
# ### Q25 (Sequence)
# What happens if you try to use a list as a dictionary key?

# %% [markdown]
# ### Q26 (Sequence)
# How do you remove an element by index?

# %% [markdown]
# ### Q27 (Sequence)
# What is 'Tuple Unpacking'? Provide an example.

# %% [markdown]
# ### Q28 (Sequence)
# How do you find the index of the first occurrence of an item?

# %% [markdown]
# ### Q29 (Sequence)
# Can a tuple contain a mutable object? What happens if you modify it?

# %% [markdown]
# ### Q30 (Sequence)
# How do you sort a list in place?

# %% [markdown]
# ### Q31 (Mapping)
# What are the requirements for an object to be used as a dictionary key?

# %% [markdown]
# ### Q32 (Mapping)
# How do you merge two dictionaries in Python 3.9+?

# %% [markdown]
# ### Q33 (Mapping)
# What is a `defaultdict`?

# %% [markdown]
# ### Q34 (Mapping)
# How do you remove a key and return its value simultaneously?

# %% [markdown]
# ### Q35 (Mapping)
# What is the time complexity of a dictionary lookup?

# %% [markdown]
# ### Q36 (Mapping)
# How do you find the intersection of two sets?

# %% [markdown]
# ### Q37 (Mapping)
# What is a `frozenset`?

# %% [markdown]
# ### Q38 (Mapping)
# How do you add multiple elements to a set at once?

# %% [markdown]
# ### Q39 (Mapping)
# Can a set contain duplicate values?

# %% [markdown]
# ### Q40 (Mapping)
# How do you iterate through both keys and values in a dictionary?

# %% [markdown]
# ### Q41 (Misc)
# Which values in Python evaluate to `False`?

# %% [markdown]
# ### Q42 (Misc)
# What is the `None` type and when is it used?

# %% [markdown]
# ### Q43 (Misc)
# How do you check the data type of a variable safely?

# %% [markdown]
# ### Q44 (Misc)
# What is 'Type Hinting'?

# %% [markdown]
# ### Q45 (Misc)
# How do you convert a list of strings into one comma-separated string?

# %% [markdown]
# ### Q46 (Misc)
# What is the result of `bool([])` and `bool([0])`?

# %% [markdown]
# ### Q47 (Misc)
# How do you convert a float to an integer? (Round vs Truncate)

# %% [markdown]
# ### Q48 (Misc)
# What is the difference between `type()` and `isinstance()`?

# %% [markdown]
# ### Q49 (Misc)
# How do you convert a string representation of a list back into a list?

# %% [markdown]
# ### Q50 (Misc)
# Explain the `bit_length()` method in integers.
